# %% [markdown]
# <a href="https://colab.research.google.com/github/anyuanay/medium/blob/main/src/working_huggingface/Working_with_HuggingFace_ch1_huging_face_ecosystem_access_token.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: Working with Hugging Face Models and Datasets
# ## Chapter 1: Getting Familiar with the Hugging Face Ecosystem
# ### Lesson 1.3: Creating an access token and logging into Hugging Face hub programmatically
#
# In this lesson, we will create an access token and log into Hugging Face hub programmtically

# %% [markdown]
# # Install Transformers and Datasets from Hugging Face

# %%
! pip install transformers[torch] datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 51.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 34.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Load a Pre-Trained BERT Model: bert-base-uncased

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
model = AutoModelForSequenceClassification.from_pretrained("bert-base-uncased")
# Out:
# ...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Log into Hugging Face Hub

# %% [markdown]
# ## First, import notebook_login from huggingface_hub

# %%
from huggingface_hub import notebook_login

# %% [markdown]
# ## Next run notebook_login()
# Copy and paste the access boken from your account in Hugging Face hub

# %%
notebook_login()

# %% [markdown]
# # Save and Share a Model to the Hub with push_to_hub()

# %%
model.push_to_hub("fine_tuned_10012023")
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/anyuanay/fine_tuned_10012023/commit/9485cec8e0e54a59673ee3737dc494b3173a7a98', commit_message='Upload BertForSequenceClassification', commit_description='', oid='9485cec8e0e54a59673ee3737dc494b3173a7a98', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Save a Model and Tokenizer to a Local Location

# %%
saved_path = "./my_model_saved"

# %%
model.save_pretrained(saved_path)

# %%
tokenizer.save_pretrained(saved_path)
# Out:
# ('./my_model_saved/tokenizer_config.json',
#  './my_model_saved/special_tokens_map.json',
#  './my_model_saved/vocab.txt',
#  './my_model_saved/added_tokens.json',
#  './my_model_saved/tokenizer.json')

# %% [markdown]
# # Load the Saved Model and Tokenizer from a Local Location

# %%
model_loaded_from_local = AutoModelForSequenceClassification.from_pretrained(saved_path)

# %%
tokenizer_loaded_from_local = AutoTokenizer.from_pretrained(saved_path)
